# %%
import sys
sys.path.append("../../")

# %load_ext autoreload
# %autoreload 2

import numpy as np
import matplotlib.pyplot as plt
from scipy.interpolate import interp1d
from scipy.integrate import quad, romberg, fixed_quad, quadrature

from axion_kSZ_source.axion_camb_wrappers.run_axion_camb import AxionCAMBWrapper
from axion_kSZ_source.theory.cosmology import Cosmology,CosmologyCustomH
from axion_kSZ_source.theory.sigma_interpolation import SigmaInterpolator
from axion_kSZ_source.theory.sigma_interpolation_FFTLog import SigmaInterpolatorFFTLog
from axion_kSZ_source.auxiliary.integration_helper import IntegrationHelper
from axion_kSZ_source.auxiliary.window_functions import WindowFunctions
from axion_kSZ_source.theory.eli_mass_functions import EliMassFunction
from axion_kSZ_source.theory.eli_mass_functions import BubbleMassFunction
from axion_kSZ_source.theory.halo_bias_new import HaloBias
from axion_kSZ_source.theory.correlation_functions import CorrelationFunctions
from axion_kSZ_source.theory.correlation_functions_FFTLog import CorrelationFunctions as CorrelationFunctionsFFTLog
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %% [markdown]
# # Table of Contents
# 1. [Cosmology](#cosmo)
#     1. [Cosmology Functions](#cosmo_functions)
#     1. [Cosmologies](#cosmologies)
# 1. [Plots and Bubble Work](#plots)
# 1. [Testing, Scratch, and Junk](#test)

# %% [markdown]
# # 1. Cosmology <a name="cosmo"></a>

# %% [markdown]
# Everything that is evaluated for a certain cosmology is stored in the various arrays below, and anytime a cosmology is updated or added, the changes to the arrays should be computed automatically, so they can be called easily and consistently at any time

# %% [markdown]
# ### A. Cosmology functions<a name="cosmo_functions"></a>

# %% [markdown]
# Reset the cosmology arrays by running this cell or by calling `reset_cosmo()`

# %%
cosmos = []
camb = []
lin_power = []
growth = []
sigmaInt = []
sigmaIntFFT = []
bubbleFunc = []
bubbleFuncFFT = []
pressSchechter = []
pressSchechterFFT = []

window = 'sharp_k'
intHelper = IntegrationHelper(2048)
z_vals_sigma = np.linspace(0,20,25) 
                                # I'm not sure what to do for this one; I don't know what Gerrit used for this.
                                # The earliest example of 'z_vals' in the other notebook is np.linspace(0,6.5,8),
                                # which is what sigmaInt would use if all the cells in that notebook were ran in
                                # order, but that doesn't seem like a large enough range.

def reset_cosmo():
    global cosmos, lin_power,growth,sigmaInt,sigmaIntFFT,bubbleFunc,bubbleFuncFFT,pressSchechter,pressSchechterFFT
    
    cosmos = []
    camb = []
    lin_power = []
    growth = []
    sigmaInt = []
    sigmaIntFFT = []
    bubbleFunc = []
    bubbleFuncFFT = []
    pressSchechter = []
    pressSchechterFFT = []
    
    window = 'sharp_k'
    intHelper = IntegrationHelper(2048)
    z_vals_sigma = np.linspace(0,20,25) 
                                    # I'm not sure what to do for this one; I don't know what Gerrit used for this.
                                    # The earliest example of 'z_vals' in the other notebook is np.linspace(0,6.5,8),
                                    # which is what sigmaInt would use if all the cells in that notebook were ran in
                                    # order, but that doesn't seem like a large enough range.

# %% [markdown]
# Functions to add a new cosmology/update the cosmology array. Make sure these have been run before adding/changing any cosmologies.

# %%
def add_cosmo(cosmo,name): # Adds a new cosmology to the arrays. Returns the cosmology array index
        
    cid = len(cosmos)
    
    outpath = "./sigma_tests/"
    fileroot ="test_"+name
    log_path = outpath+"sigma_test_"+name+"_log.log"

    thisCamb = AxionCAMBWrapper(outpath, fileroot, log_path)
    thisCamb(cosmo)
    camb.append(thisCamb)
    cosmo.set_H_interpolation(thisCamb)
    
    lin_power.append(thisCamb.get_linear_power(extrap_kmax=1e3, extrap_kmin=1e-6))
    growth.append(thisCamb.get_growth())
    
    thisSigmaInt = SigmaInterpolator(cosmo,lin_power[cid],growth[cid],1e1,1e20,z_vals_sigma,intHelper,Nr=1024,window_function=window)
    thisSigmaInt.compute(1e-4,1e3)
    sigmaInt.append(thisSigmaInt)
    
    thisSigmaIntFFT =  SigmaInterpolatorFFTLog(cosmo, lin_power[cid], growth[cid], z_vals_sigma, 1e-4, 1e3, Nr=1024, window_function=window)
    thisSigmaIntFFT.compute()
    sigmaIntFFT.append(thisSigmaIntFFT)
    
    bubbleFunc.append(BubbleMassFunction(cosmo,thisSigmaInt))
    bubbleFuncFFT.append(BubbleMassFunction(cosmo,thisSigmaIntFFT))
    
    pressSchechter.append(EliMassFunction(cosmo,thisSigmaInt))
    pressSchechterFFT.append(EliMassFunction(cosmo,thisSigmaIntFFT))
    
    cosmos.append(cosmo)
    
    return cid

def update_cosmo(cosmo,i): # Updates the arrays' ith position with cosmo
    
    thisCamb = camb[i]
    thisCamb(cosmo)
    camb[i] = thisCamb
    cosmo.set_H_interpolation(thisCamb)

    lin_power[i] = thisCamb.get_linear_power(extrap_kmax=1e3, extrap_kmin=1e-6)
    growth[i] = thisCamb.get_growth()
    
    thisSigmaInt = SigmaInterpolator(cosmo,lin_power[i],growth[i],1e1,1e20,z_vals_sigma,intHelper,Nr=1024,window_function=window)
    thisSigmaInt.compute(1e-4,1e3)
    sigmaInt[i] = thisSigmaInt
    
    thisSigmaIntFFT =  SigmaInterpolatorFFTLog(cosmo, lin_power[i], growth[i], z_vals_sigma, 1e-4, 1e3, Nr=1024, window_function=window)
    thisSigmaIntFFT.compute()
    sigmaIntFFT[i] = thisSigmaIntFFT
    
    bubbleFunc[i] = BubbleMassFunction(cosmo,thisSigmaInt)
    bubbleFuncFFT[i] = BubbleMassFunction(cosmo,thisSigmaIntFFT)
    
    pressSchechter[i] = EliMassFunction(cosmo,thisSigmaInt)
    pressSchecterFFT[i] = EliMassFunction(cosmo,thisSigmaIntFFT)
    
    cosmos[i] = cosmo
    
    return 1

# %% [markdown]
# ### B. Cosmologies<a name='cosmologies'></a>
#
# Change the parameters at the beginning of the cell to update an existing cosmology, or add a new cell in the same style to add a new cosmology. Run the cell to update/add the cosmology.

# %%
# cosmo0

m_ax = 1e-26
ax_frac = 0.005
h_param = 0.72
rhff = True

newCosmo0 = [m_ax,ax_frac,h_param,rhff]
try:
    oldCosmo0
except NameError:
    oldCosmo0 = newCosmo0
    try:
        cosmo0
    except NameError:
        cosmo0 = Cosmology.generate(m_axion=m_ax,axion_frac=ax_frac,h=h_param,read_H_from_file=rhff)
        add_cosmo(cosmo0,'cosmo0')
    else:
        try:
            i = cosmos.index(cosmo0)
        except ValueError:
            add_cosmo(cosmo0,'cosmo0')
        else:
            cosmo0 = Cosmology.generate(m_axion=m_ax,axion_frac=ax_frac,h=h_param,read_H_from_file=rhff)
            update_cosmo(cosmo0,i)
else:
    try:
        cosmo0
    except NameError:
        cosmo0 = Cosmology.generate(m_axion=m_ax,axion_frac=ax_frac,h=h_param,read_H_from_file=rhff)
        add_cosmo(cosmo0,'cosmo0')
    else: 
        try:
            i = cosmos.index(cosmo0)
        except ValueError:
            if not oldCosmo0 == newCosmo0:
                cosmo0 = Cosmology.generate(m_axion=m_ax,axion_frac=ax_frac,h=h_param,read_H_from_file=rhff)
            add_cosmo(cosmo0,'cosmo0')
        else :
            if not oldCosmo0 == newCosmo0:
                cosmo0 = Cosmology.generate(m_axion=m_ax,axion_frac=ax_frac,h=h_param,read_H_from_file=rhff)
                update_cosmo(cosmo0,i)
# Out:
# Note: The following floating-point exceptions are signalling: IEEE_INVALID_FLAG IEEE_DIVIDE_BY_ZERO IEEE_UNDERFLOW_FLAG IEEE_DENORMAL
# /home/emelnick/anaconda3/lib/python3.9/site-packages/mcfit/mcfit.py:126: UserWarning: The default value of lowring has been changed to False, set it to True if you cannot reproduce previous results
#   warnings.warn("The default value of lowring has been changed to False, "

# %%
# cosmo1

m_ax = 1e-26
ax_frac = 0.05
h_param = 0.72
rhff = True

newCosmo1 = [m_ax,ax_frac,h_param,rhff]
try:
    oldCosmo1
except NameError:
    oldCosmo1 = newCosmo1
    try:
        cosmo1
    except NameError:
        cosmo1 = Cosmology.generate(m_axion=m_ax,axion_frac=ax_frac,h=h_param,read_H_from_file=rhff)
        add_cosmo(cosmo1,'cosmo1')
    else:
        try:
            i = cosmos.index(cosmo1)
        except ValueError:
            add_cosmo(cosmo1,'cosmo1')
        else:
            cosmo1 = Cosmology.generate(m_axion=m_ax,axion_frac=ax_frac,h=h_param,read_H_from_file=rhff)
            update_cosmo(cosmo1,i)
else:
    try:
        cosmo1
    except NameError:
        cosmo1 = Cosmology.generate(m_axion=m_ax,axion_frac=ax_frac,h=h_param,read_H_from_file=rhff)
        add_cosmo(cosmo1,'cosmo1')
    else: 
        try:
            i = cosmos.index(cosmo1)
        except ValueError:
            if not oldCosmo1 == newCosmo1:
                cosmo1 = Cosmology.generate(m_axion=m_ax,axion_frac=ax_frac,h=h_param,read_H_from_file=rhff)
            add_cosmo(cosmo1,'cosmo1')
        else :
            if not oldCosmo1 == newCosmo1:
                cosmo1 = Cosmology.generate(m_axion=m_ax,axion_frac=ax_frac,h=h_param,read_H_from_file=rhff)
                update_cosmo(cosmo1,i)
# Out:
# Note: The following floating-point exceptions are signalling: IEEE_INVALID_FLAG IEEE_DIVIDE_BY_ZERO IEEE_UNDERFLOW_FLAG IEEE_DENORMAL

# %%
# cosmo2

m_ax = 1e-26
ax_frac = 0.5
h_param = 0.72
rhff = True

newCosmo2 = [m_ax,ax_frac,h_param,rhff]
try:
    oldCosmo2
except NameError:
    oldCosmo2 = newCosmo2
    try:
        cosmo2
    except NameError:
        cosmo2 = Cosmology.generate(m_axion=m_ax,axion_frac=ax_frac,h=h_param,read_H_from_file=rhff)
        add_cosmo(cosmo2,'cosmo2')
    else:
        try:
            i = cosmos.index(cosmo2)
        except ValueError:
            add_cosmo(cosmo2,'cosmo2')
        else:
            cosmo2 = Cosmology.generate(m_axion=m_ax,axion_frac=ax_frac,h=h_param,read_H_from_file=rhff)
            update_cosmo(cosmo2,i)
else:
    try:
        cosmo2
    except NameError:
        cosmo2 = Cosmology.generate(m_axion=m_ax,axion_frac=ax_frac,h=h_param,read_H_from_file=rhff)
        add_cosmo(cosmo2,'cosmo2')
    else: 
        try:
            i = cosmos.index(cosmo2)
        except ValueError:
            if not oldCosmo2 == newCosmo2:
                cosmo2 = Cosmology.generate(m_axion=m_ax,axion_frac=ax_frac,h=h_param,read_H_from_file=rhff)
            add_cosmo(cosmo2,'cosmo2')
        else :
            if not oldCosmo2 == newCosmo2:
                cosmo2 = Cosmology.generate(m_axion=m_ax,axion_frac=ax_frac,h=h_param,read_H_from_file=rhff)
                update_cosmo(cosmo2,i)
# Out:
# Note: The following floating-point exceptions are signalling: IEEE_INVALID_FLAG IEEE_DIVIDE_BY_ZERO IEEE_UNDERFLOW_FLAG IEEE_DENORMAL

# %%
# cosmo3

m_ax = 1e-24
ax_frac = 5e-8
h_param = 0.72
rhff = True

newCosmo3 = [m_ax,ax_frac,h_param,rhff]
try:
    oldCosmo3
except NameError:
    oldCosmo3 = newCosmo3
    try:
        cosmo3
    except NameError:
        cosmo3 = Cosmology.generate(m_axion=m_ax,axion_frac=ax_frac,h=h_param,read_H_from_file=rhff)
        add_cosmo(cosmo3,'cosmo3')
    else:
        try:
            i = cosmos.index(cosmo3)
        except ValueError:
            add_cosmo(cosmo3,'cosmo3')
        else:
            cosmo3 = Cosmology.generate(m_axion=m_ax,axion_frac=ax_frac,h=h_param,read_H_from_file=rhff)
            update_cosmo(cosmo3,i)
else:
    try:
        cosmo3
    except NameError:
        cosmo3 = Cosmology.generate(m_axion=m_ax,axion_frac=ax_frac,h=h_param,read_H_from_file=rhff)
        add_cosmo(cosmo3,'cosmo3')
    else: 
        try:
            i = cosmos.index(cosmo3)
        except ValueError:
            if not oldCosmo3 == newCosmo3:
                cosmo3 = Cosmology.generate(m_axion=m_ax,axion_frac=ax_frac,h=h_param,read_H_from_file=rhff)
            add_cosmo(cosmo3,'cosmo3')
        else :
            if not oldCosmo3 == newCosmo3:
                cosmo3 = Cosmology.generate(m_axion=m_ax,axion_frac=ax_frac,h=h_param,read_H_from_file=rhff)
                update_cosmo(cosmo3,i)
# Out:
# Note: The following floating-point exceptions are signalling: IEEE_INVALID_FLAG IEEE_DIVIDE_BY_ZERO IEEE_UNDERFLOW_FLAG IEEE_DENORMAL
# /home/emelnick/anaconda3/lib/python3.9/site-packages/mcfit/mcfit.py:126: UserWarning: The default value of lowring has been changed to False, set it to True if you cannot reproduce previous results
#   warnings.warn("The default value of lowring has been changed to False, "

# %% [markdown]
# # 2. Plots and Bubble Work<a name="plots"></a>

# %% [markdown]
# ### A. Plots of cosmology information

# %% [markdown]
# #### `Lin_power` plot

# %%
k_vals = np.logspace(-6, 3, 100)
plt.loglog(k_vals, lin_power[0](k_vals),label='0.005')
plt.loglog(k_vals, lin_power[1](k_vals),label='0.05')
plt.loglog(k_vals, lin_power[2](k_vals),label='0.5')
plt.legend()

# %% [markdown]
# #### `growth` plot

# %%
z_vals=np.linspace(0, 6.5, 8)
plt.plot(z_vals, growth[0](1e0, z_vals),label='0.005')
plt.plot(z_vals, growth[1](1e0, z_vals),label='0.05')
plt.plot(z_vals, growth[2](1e0, z_vals),label='0.5')
plt.legend()

# %% [markdown]
# #### Normal $\sigma$ and FFT $\sigma$ plot as a function of mass for $m$ ranging from $10^6 M_{\text{sun}}$ to $10^{16} M_{\text{sun}}$

# %%
m_vals = np.logspace(6, 16, 100)
plt.loglog(m_vals, sigmaIntFFT[0](m_vals, 0.0),label='0.005')
plt.loglog(m_vals, sigmaIntFFT[1](m_vals, 0.0),label='0.05')
plt.loglog(m_vals, sigmaIntFFT[2](m_vals,0.0),label='0.5')
plt.legend()

# %%
m_vals = np.logspace(6, 16, 100)
plt.loglog(m_vals, sigmaInt[0](m_vals, 0.0),label='0.005')
plt.loglog(m_vals, sigmaInt[1](m_vals, 0.0),label='0.05')
plt.loglog(m_vals, sigmaInt[2](m_vals,0.0),label='0.5')
plt.legend()

# %% [markdown]
# #### Bubble mass function with FFT variance

# %%
m_vals = np.logspace(8, 13, 100)
z = 12
plt.plot(m_vals, bubbleFuncFFT[0](m_vals,z),label='0.005')
plt.plot(m_vals, bubbleFuncFFT[1](m_vals,z),label='0.05')
plt.plot(m_vals, bubbleFuncFFT[2](m_vals,z),label='0.5')
plt.plot(m_vals, bubbleFuncFFT[3](m_vals,z),label='5e-8')
plt.xscale('log')
plt.legend()

# %% [markdown]
# #### Bubble mass function with normal variance

# %%
m_vals = np.logspace(8, 13, 100)
z = 12
plt.plot(m_vals, bubbleFunc[0](m_vals,z),label='0.005')
plt.plot(m_vals, bubbleFunc[1](m_vals,z),label='0.05')
plt.plot(m_vals, bubbleFunc[2](m_vals,z),label='0.5')
plt.plot(m_vals, bubbleFunc[3](m_vals,z),label='5e-8')
plt.xscale('log')
plt.legend()

# %% [markdown]
# #### Press-Schechter mass function with normal variance

# %%
m_vals = np.logspace(9,15,100)
z = 6
plt.loglog(m_vals,pressSchechter[0](m_vals,z),label='0.005')
plt.loglog(m_vals,pressSchechter[1](m_vals,z),label='0.05')
plt.loglog(m_vals,pressSchechter[2](m_vals,z),label='0.5')

# %% [markdown]
# #### Press-Schechter mass function with FFT variance

# %%
m_vals = np.logspace(9,15,100)
z = 6
plt.loglog(m_vals,pressSchechterFFT[0](m_vals,z),label='0.005')
plt.loglog(m_vals,pressSchechterFFT[1](m_vals,z),label='0.05')
plt.loglog(m_vals,pressSchechterFFT[2](m_vals,z),label='0.5')

# %% [markdown]
# ## Furlanetto Figure 2: Bubble distribution

# %% [markdown]
# Function definitions to convert mass to/from radius

# %%
def m_from_R(R,cosmo,h_adjust=False):
    rho = cosmo.rho_mean
    
    # Determining omega & h adjustments
    if h_adjust == True:
        rho /= cosmo.h**2

    return (4/3) * np.pi * R**3 * rho * (1+z)**3



def R_from_m(m,cosmo,h_adjust=False): 
    rho = cosmo.rho_mean
    
    # Determining omega & h adjustments
    if h_adjust == True:
        rho /= cosmo.h**2

    return (3*m/(4*np.pi*rho))**(1/3)

# %% [markdown]
# Plotting $\overline{Q}^{-1}V\frac{\text{d}n}{\text{d}\ln R}$

# %%
z_vals = [12,16,18]
zeta = 40
for z in z_vals:
    for i in range(len(cosmos)):
        mMin = (1.308695e-10) * ((cosmos[i].RHO_C*1000 * cosmos[i].OmegaM)**(-1/2)) * ((1+z)**(-3/2)) * (1e4)**(3/2) # Included Delta in pre-eval w/ cosmology.py OmegaM property and in solar masses
#         mMin = (3.95284708e8/cosmos[i].h) * (1/(1+z))**(3/2)
        rho = cosmos[i].rho_mean * (1+z)**3
        integrand = lambda m: (1/rho) * bubbleFunc[i](m,z)
        Q = quad(integrand,mMin,np.inf)[0]
        
#         R_vals = np.logspace(-3,2,500)
#         m_vals = (1/zeta)*m_from_R(R_vals,cosmos[i])
      
#         m_vals = np.logspace(np.log10(mMin),20,500)
#         R_vals = R_from_m(m_vals,cosmos[i])
        
        print("Q =",Q)
        title1 = f'axion fraction = {cosmos[i].axion_frac:.3f}, z = {z}'

        plt.figure()
        plt.plot(R_vals,3*(1/Q)*(m_vals/rho)*bubbleFunc[i](m_vals,z))
#         plt.axvline(R_from_m(zeta*mMin,cosmos[i],z),c='black',linestyle='dashed')
        plt.xscale('log')
        plt.title(title1)
# Out:
# Q = 1.0933925757058473e-10
# Q = 1.2035381514222312e-10
# Q = 1.4005692536529245e-54
# Q = 1.0177923626368999e-10
# Q = 6.2095343905758e-11
# Q = 2.681828440797754e-11
# Q = 2.5591625137012486e-77
# Q = 6.592756622224795e-11
# Q = 3.139891206794543e-11
# Q = 9.396031715170859e-12
# Q = 2.0403243811005098e-89
# Q = 3.4628423089815576e-11

# %% [markdown]
# ## Testing integration methods

# %% [markdown]
# Want to get a stable method for determining $\overline{Q}$ that hopefully doesn't throw out a bunch of warnings.

# %% [markdown]
# #### Romberg

# %%
# z_vals = [0,12,16,18]
z_vals = np.linspace(0,20,101)
# z_vals = [0]
zeta = 40
i=3
Q_vals = []
Q_vals_log = []

for z in z_vals:
#     mMin = (1.308695e-10) * ((cosmos[i].RHO_C*1000 * cosmos[i].OmegaM)**(-1/2)) * ((1+z)**(-3/2)) * (1e4)**(3/2) # Included Delta in pre-eval w/ cosmology.py OmegaM property and in solar masses
    mMin = (3.95284708e8/cosmos[i].h) * (1/(1+z))**(3/2)
#     mMin = 1e1
    log_mMin = np.log10(mMin)
    
    rho = cosmos[i].rho_mean * (1+z)**3
    
    integrand = lambda m: (1/rho) * pressSchechter[i](m,z)
    integrand_log = lambda m: (10**m/rho) * pressSchechter[i](10**m,z)
    
    Q_vals.append(romberg(integrand,mMin,1e24,divmax=10))
    Q_vals_log.append(romberg(integrand_log,log_mMin,24,divmax=10))
    
#     m_valslin = np.linspace(1,16,100)
#     m_valslog = np.logspace(1,16,100)
            

    
#     R_vals = np.logspace(-3,2,500)
#     m_vals = (1/zeta)*m_from_R(R_vals,cosmos[i])
#     print(bubbleFunc[i](m_vals,z))

#     m_vals = np.logspace(np.log10(mMin),20,500)
#     R_vals = R_from_m(zeta*m_vals,cosmos[i])

#     title1 = f'axion fraction = {cosmos[i].axion_frac}, z = {z}'

#     plt.figure()
#     plt.plot(R_vals,3*(1/Q)*(m_vals/rho) * pressSchechter[i](m_vals,z))
#         plt.axvline(R_from_m(zeta*mMin,cosmos[i],z),c='black',linestyle='dashed')
#     plt.xscale('log')
#     plt.title(title1)

plt.plot(z_vals,Q_vals)
plt.yscale('log')
plt.title('linear m')
plt.figure()

plt.plot(z_vals,Q_vals_log)
plt.yscale('log')
plt.title('logarithmic m')
# Out:
# /home/emelnick/.local/lib/python3.9/site-packages/scipy/integrate/_quadrature.py:850: AccuracyWarning: divmax (10) exceeded. Latest difference = 1.083327e+10
#   warnings.warn(
# /home/emelnick/.local/lib/python3.9/site-packages/scipy/integrate/_quadrature.py:850: AccuracyWarning: divmax (10) exceeded. Latest difference = 4.738581e-06
#   warnings.warn(
# /home/emelnick/.local/lib/python3.9/site-packages/scipy/integrate/_quadrature.py:850: AccuracyWarning: divmax (10) exceeded. Latest difference = 8.475216e+09
#   warnings.warn(
# /home/emelnick/.local/lib/python3.9/site-packages/scipy/integrate/_quadrature.py:850: AccuracyWarning: divmax (10) exceeded. Latest difference = 7.259127e-07
#   warnings.warn(
# /home/emelnick/.local/lib/python3.9/site-packages/scipy/integrate/_quadrature.py:850: AccuracyWarning: divmax (10) exceeded. Latest difference = 7.023962e+09
#   warnings.warn(
# /home/emelnick/.local/lib/python3.9/site-packages/scipy/integrate/_quadrature.py:850: AccuracyWarning: divmax (10) exceeded. Latest difference = 1.375030e-07
#   warnings.warn(
# /home/emelnick/.local/lib/python3.9/site-packages/scipy/integrate/_quadrature.py:850: AccuracyWarning: divmax (10) exceeded. Latest difference = 6.111331e+09
#   warnings.warn(
# /home/emelnick/.local/lib/python3.9/site-packages/scipy/integrate/_quadrature.py:850: AccuracyWarning: divmax (10) exceeded. Latest difference = 4.431992e-07
#   warnings.warn(
# /home/emelnick/.local/lib/python3.9/site-packages/scipy/integrate/_quadrature.py:850: AccuracyWarning: divmax (10) exceeded. Latest difference = 5.563315e+09
#   warnings.warn(
# /home/emelnick/.local/lib/python3.9/site-packages/scipy/integrate/_quadrature.py:850: AccuracyWarning: divmax (10) exceeded. Latest difference = 2.670193e-07
#   warnings.warn(
# /home/emelnick/.local/lib/python3.9/site-packages/scipy/integrate/_quadrature.py:850: AccuracyWarning: divmax (10) exceeded. Latest difference = 4.950447e+09
#   warnings.warn(
# /home/emelnick/.local/lib/python3.9/site-packages/scipy/integrate/_quadrature.py:850: AccuracyWarning: divmax (10) exceeded. Latest difference = 1.487754e-07
#   warnings.warn(
# /home/emelnick/.local/lib/python3.9/site-packages/scipy/integrate/_quadrature.py:850: AccuracyWarning: divmax (10) exceeded. Latest difference = 4.452473e+09
#   warnings.warn(
# /home/emelnick/.local/lib/python3.9/site-packages/scipy/integrate/_quadrature.py:850: AccuracyWarning: divmax (10) exceeded. Latest difference = 4.817931e-08
#   warnings.warn(
# /home/emelnick/.local/lib/python3.9/site-packages/scipy/integrate/_quadrature.py:850: AccuracyWarning: divmax (10) exceeded. Latest difference = 4.087982e+09
#   warnings.warn(
# /home/emelnick/.local/lib/python3.9/site-packages/scipy/integrate/_quadrature.py:850: AccuracyWarning: divmax (10) exceeded. Latest difference = 3.827584e+09
#   warnings.warn(
# /home/emelnick/.local/lib/python3.9/site-packages/scipy/integrate/_quadrature.py:850: AccuracyWarning: divmax (10) exceeded. Latest difference = 3.544693e+09
#   warnings.warn(
# /home/emelnick/.local/lib/python3.9/site-packages/scipy/integrate/_quadrature.py:850: AccuracyWarning: divmax (10) exceeded. Latest difference = 3.271509e+09
#   warnings.warn(
# /home/emelnick/.local/lib/python3.9/site-packages/scipy/integrate/_quadrature.py:850: AccuracyWarning: divmax (10) exceeded. Latest difference = 3.048204e+09
#   warnings.warn(
# /home/emelnick/.local/lib/python3.9/site-packages/scipy/integrate/_quadrature.py:850: AccuracyWarning: divmax (10) exceeded. Latest difference = 2.863747e+09
#   warnings.warn(
# /home/emelnick/.local/lib/python3.9/site-packages/scipy/integrate/_quadrature.py:850: AccuracyWarning: divmax (10) exceeded. Latest difference = 2.683247e+09
#   warnings.warn(
# /home/emelnick/.local/lib/python3.9/site-packages/scipy/integrate/_quadrature.py:850: AccuracyWarning: divmax (10) exceeded. Latest difference = 2.503838e+09
#   warnings.warn(
# /home/emelnick/.local/lib/python3.9/site-packages/scipy/integrate/_quadrature.py:850: AccuracyWarning: divmax (10) exceeded. Latest difference = 2.346451e+09
#   warnings.warn(
# /home/emelnick/.local/lib/python3.9/site-packages/scipy/integrate/_quadrature.py:850: AccuracyWarning: divmax (10) exceeded. Latest difference = 2.205852e+09
#   warnings.warn(
# /home/emelnick/.local/lib/python3.9/site-packages/scipy/integrate/_quadrature.py:850: AccuracyWarning: divmax (10) exceeded. Latest difference = 2.072657e+09
#   warnings.warn(
# /home/emelnick/.local/lib/python3.9/site-packages/scipy/integrate/_quadrature.py:850: AccuracyWarning: divmax (10) exceeded. Latest difference = 1.943158e+09
#   warnings.warn(
# /home/emelnick/.local/lib/python3.9/site-packages/scipy/integrate/_quadrature.py:850: AccuracyWarning: divmax (10) exceeded. Latest difference = 1.824581e+09
#   warnings.warn(
# /home/emelnick/.local/lib/python3.9/site-packages/scipy/integrate/_quadrature.py:850: AccuracyWarning: divmax (10) exceeded. Latest difference = 1.714170e+09
#   warnings.warn(
# /home/emelnick/.local/lib/python3.9/site-packages/scipy/integrate/_quadrature.py:850: AccuracyWarning: divmax (10) exceeded. Latest difference = 1.609505e+09
#   warnings.warn(
# /home/emelnick/.local/lib/python3.9/site-packages/scipy/integrate/_quadrature.py:850: AccuracyWarning: divmax (10) exceeded. Latest difference = 1.512204e+09
#   warnings.warn(
# /home/emelnick/.local/lib/python3.9/site-packages/scipy/integrate/_quadrature.py:850: AccuracyWarning: divmax (10) exceeded. Latest difference = 1.420735e+09
#   warnings.warn(
# /home/emelnick/.local/lib/python3.9/site-packages/scipy/integrate/_quadrature.py:850: AccuracyWarning: divmax (10) exceeded. Latest difference = 1.333584e+09
#   warnings.warn(
# /home/emelnick/.local/lib/python3.9/site-packages/scipy/integrate/_quadrature.py:850: AccuracyWarning: divmax (10) exceeded. Latest difference = 1.249235e+09
#   warnings.warn(
# /home/emelnick/.local/lib/python3.9/site-packages/scipy/integrate/_quadrature.py:850: AccuracyWarning: divmax (10) exceeded. Latest difference = 1.174345e+09
#   warnings.warn(
# /home/emelnick/.local/lib/python3.9/site-packages/scipy/integrate/_quadrature.py:850: AccuracyWarning: divmax (10) exceeded. Latest difference = 1.102821e+09
#   warnings.warn(
# /home/emelnick/.local/lib/python3.9/site-packages/scipy/integrate/_quadrature.py:850: AccuracyWarning: divmax (10) exceeded. Latest difference = 1.033824e+09
#   warnings.warn(
# /home/emelnick/.local/lib/python3.9/site-packages/scipy/integrate/_quadrature.py:850: AccuracyWarning: divmax (10) exceeded. Latest difference = 9.663786e+08
#   warnings.warn(
# /home/emelnick/.local/lib/python3.9/site-packages/scipy/integrate/_quadrature.py:850: AccuracyWarning: divmax (10) exceeded. Latest difference = 9.066867e+08
#   warnings.warn(
# /home/emelnick/.local/lib/python3.9/site-packages/scipy/integrate/_quadrature.py:850: AccuracyWarning: divmax (10) exceeded. Latest difference = 8.503682e+08
#   warnings.warn(
# /home/emelnick/.local/lib/python3.9/site-packages/scipy/integrate/_quadrature.py:850: AccuracyWarning: divmax (10) exceeded. Latest difference = 7.957027e+08
#   warnings.warn(
# /home/emelnick/.local/lib/python3.9/site-packages/scipy/integrate/_quadrature.py:850: AccuracyWarning: divmax (10) exceeded. Latest difference = 7.422278e+08
#   warnings.warn(
# /home/emelnick/.local/lib/python3.9/site-packages/scipy/integrate/_quadrature.py:850: AccuracyWarning: divmax (10) exceeded. Latest difference = 6.943970e+08
#   warnings.warn(
# /home/emelnick/.local/lib/python3.9/site-packages/scipy/integrate/_quadrature.py:850: AccuracyWarning: divmax (10) exceeded. Latest difference = 6.502896e+08
#   warnings.warn(
# /home/emelnick/.local/lib/python3.9/site-packages/scipy/integrate/_quadrature.py:850: AccuracyWarning: divmax (10) exceeded. Latest difference = 6.073587e+08
#   warnings.warn(
# /home/emelnick/.local/lib/python3.9/site-packages/scipy/integrate/_quadrature.py:850: AccuracyWarning: divmax (10) exceeded. Latest difference = 5.653503e+08
#   warnings.warn(
# /home/emelnick/.local/lib/python3.9/site-packages/scipy/integrate/_quadrature.py:850: AccuracyWarning: divmax (10) exceeded. Latest difference = 5.270483e+08
#   warnings.warn(
# /home/emelnick/.local/lib/python3.9/site-packages/scipy/integrate/_quadrature.py:850: AccuracyWarning: divmax (10) exceeded. Latest difference = 4.926805e+08
#   warnings.warn(
# /home/emelnick/.local/lib/python3.9/site-packages/scipy/integrate/_quadrature.py:850: AccuracyWarning: divmax (10) exceeded. Latest difference = 4.592148e+08
#   warnings.warn(
# /home/emelnick/.local/lib/python3.9/site-packages/scipy/integrate/_quadrature.py:850: AccuracyWarning: divmax (10) exceeded. Latest difference = 4.265145e+08
#   warnings.warn(
# /home/emelnick/.local/lib/python3.9/site-packages/scipy/integrate/_quadrature.py:850: AccuracyWarning: divmax (10) exceeded. Latest difference = 3.960449e+08
#   warnings.warn(
# /home/emelnick/.local/lib/python3.9/site-packages/scipy/integrate/_quadrature.py:850: AccuracyWarning: divmax (10) exceeded. Latest difference = 3.694702e+08
#   warnings.warn(
# /home/emelnick/.local/lib/python3.9/site-packages/scipy/integrate/_quadrature.py:850: AccuracyWarning: divmax (10) exceeded. Latest difference = 3.436208e+08
#   warnings.warn(
# /home/emelnick/.local/lib/python3.9/site-packages/scipy/integrate/_quadrature.py:850: AccuracyWarning: divmax (10) exceeded. Latest difference = 3.184235e+08
#   warnings.warn(
# /home/emelnick/.local/lib/python3.9/site-packages/scipy/integrate/_quadrature.py:850: AccuracyWarning: divmax (10) exceeded. Latest difference = 2.944285e+08
#   warnings.warn(
# /home/emelnick/.local/lib/python3.9/site-packages/scipy/integrate/_quadrature.py:850: AccuracyWarning: divmax (10) exceeded. Latest difference = 2.740664e+08
#   warnings.warn(
# /home/emelnick/.local/lib/python3.9/site-packages/scipy/integrate/_quadrature.py:850: AccuracyWarning: divmax (10) exceeded. Latest difference = 2.542789e+08
#   warnings.warn(
# /home/emelnick/.local/lib/python3.9/site-packages/scipy/integrate/_quadrature.py:850: AccuracyWarning: divmax (10) exceeded. Latest difference = 2.350426e+08
#   warnings.warn(
# /home/emelnick/.local/lib/python3.9/site-packages/scipy/integrate/_quadrature.py:850: AccuracyWarning: divmax (10) exceeded. Latest difference = 2.163423e+08
#   warnings.warn(
# /home/emelnick/.local/lib/python3.9/site-packages/scipy/integrate/_quadrature.py:850: AccuracyWarning: divmax (10) exceeded. Latest difference = 2.008906e+08
#   warnings.warn(
# /home/emelnick/.local/lib/python3.9/site-packages/scipy/integrate/_quadrature.py:850: AccuracyWarning: divmax (10) exceeded. Latest difference = 1.859352e+08
#   warnings.warn(
# /home/emelnick/.local/lib/python3.9/site-packages/scipy/integrate/_quadrature.py:850: AccuracyWarning: divmax (10) exceeded. Latest difference = 1.714565e+08
#   warnings.warn(
# /home/emelnick/.local/lib/python3.9/site-packages/scipy/integrate/_quadrature.py:850: AccuracyWarning: divmax (10) exceeded. Latest difference = 1.574403e+08
#   warnings.warn(
# /home/emelnick/.local/lib/python3.9/site-packages/scipy/integrate/_quadrature.py:850: AccuracyWarning: divmax (10) exceeded. Latest difference = 1.455361e+08
#   warnings.warn(
# /home/emelnick/.local/lib/python3.9/site-packages/scipy/integrate/_quadrature.py:850: AccuracyWarning: divmax (10) exceeded. Latest difference = 1.343723e+08
#   warnings.warn(
# /home/emelnick/.local/lib/python3.9/site-packages/scipy/integrate/_quadrature.py:850: AccuracyWarning: divmax (10) exceeded. Latest difference = 1.236045e+08
#   warnings.warn(
# /home/emelnick/.local/lib/python3.9/site-packages/scipy/integrate/_quadrature.py:850: AccuracyWarning: divmax (10) exceeded. Latest difference = 1.132255e+08
#   warnings.warn(
# /home/emelnick/.local/lib/python3.9/site-packages/scipy/integrate/_quadrature.py:850: AccuracyWarning: divmax (10) exceeded. Latest difference = 1.041820e+08
#   warnings.warn(
# /home/emelnick/.local/lib/python3.9/site-packages/scipy/integrate/_quadrature.py:850: AccuracyWarning: divmax (10) exceeded. Latest difference = 9.595038e+07
#   warnings.warn(
# /home/emelnick/.local/lib/python3.9/site-packages/scipy/integrate/_quadrature.py:850: AccuracyWarning: divmax (10) exceeded. Latest difference = 8.804095e+07
#   warnings.warn(
# /home/emelnick/.local/lib/python3.9/site-packages/scipy/integrate/_quadrature.py:850: AccuracyWarning: divmax (10) exceeded. Latest difference = 8.045001e+07
#   warnings.warn(
# /home/emelnick/.local/lib/python3.9/site-packages/scipy/integrate/_quadrature.py:850: AccuracyWarning: divmax (10) exceeded. Latest difference = 7.367890e+07
#   warnings.warn(
# /home/emelnick/.local/lib/python3.9/site-packages/scipy/integrate/_quadrature.py:850: AccuracyWarning: divmax (10) exceeded. Latest difference = 6.768507e+07
#   warnings.warn(
# /home/emelnick/.local/lib/python3.9/site-packages/scipy/integrate/_quadrature.py:850: AccuracyWarning: divmax (10) exceeded. Latest difference = 6.194845e+07
#   warnings.warn(
# /home/emelnick/.local/lib/python3.9/site-packages/scipy/integrate/_quadrature.py:850: AccuracyWarning: divmax (10) exceeded. Latest difference = 5.646638e+07
#   warnings.warn(
# /home/emelnick/.local/lib/python3.9/site-packages/scipy/integrate/_quadrature.py:850: AccuracyWarning: divmax (10) exceeded. Latest difference = 5.147083e+07
#   warnings.warn(
# /home/emelnick/.local/lib/python3.9/site-packages/scipy/integrate/_quadrature.py:850: AccuracyWarning: divmax (10) exceeded. Latest difference = 4.716213e+07
#   warnings.warn(
# /home/emelnick/.local/lib/python3.9/site-packages/scipy/integrate/_quadrature.py:850: AccuracyWarning: divmax (10) exceeded. Latest difference = 4.305452e+07
#   warnings.warn(
# /home/emelnick/.local/lib/python3.9/site-packages/scipy/integrate/_quadrature.py:850: AccuracyWarning: divmax (10) exceeded. Latest difference = 3.914575e+07
#   warnings.warn(
# /home/emelnick/.local/lib/python3.9/site-packages/scipy/integrate/_quadrature.py:850: AccuracyWarning: divmax (10) exceeded. Latest difference = 3.551438e+07
#   warnings.warn(
# /home/emelnick/.local/lib/python3.9/site-packages/scipy/integrate/_quadrature.py:850: AccuracyWarning: divmax (10) exceeded. Latest difference = 3.245699e+07
#   warnings.warn(
# /home/emelnick/.local/lib/python3.9/site-packages/scipy/integrate/_quadrature.py:850: AccuracyWarning: divmax (10) exceeded. Latest difference = 2.955372e+07
#   warnings.warn(
# /home/emelnick/.local/lib/python3.9/site-packages/scipy/integrate/_quadrature.py:850: AccuracyWarning: divmax (10) exceeded. Latest difference = 2.680258e+07
#   warnings.warn(
# /home/emelnick/.local/lib/python3.9/site-packages/scipy/integrate/_quadrature.py:850: AccuracyWarning: divmax (10) exceeded. Latest difference = 2.420158e+07
#   warnings.warn(
# /home/emelnick/.local/lib/python3.9/site-packages/scipy/integrate/_quadrature.py:850: AccuracyWarning: divmax (10) exceeded. Latest difference = 2.205989e+07
#   warnings.warn(
# /home/emelnick/.local/lib/python3.9/site-packages/scipy/integrate/_quadrature.py:850: AccuracyWarning: divmax (10) exceeded. Latest difference = 2.003339e+07
#   warnings.warn(
# /home/emelnick/.local/lib/python3.9/site-packages/scipy/integrate/_quadrature.py:850: AccuracyWarning: divmax (10) exceeded. Latest difference = 1.812018e+07
#   warnings.warn(
# /home/emelnick/.local/lib/python3.9/site-packages/scipy/integrate/_quadrature.py:850: AccuracyWarning: divmax (10) exceeded. Latest difference = 1.631914e+07
#   warnings.warn(
# /home/emelnick/.local/lib/python3.9/site-packages/scipy/integrate/_quadrature.py:850: AccuracyWarning: divmax (10) exceeded. Latest difference = 1.480143e+07
#   warnings.warn(
# /home/emelnick/.local/lib/python3.9/site-packages/scipy/integrate/_quadrature.py:850: AccuracyWarning: divmax (10) exceeded. Latest difference = 1.340598e+07
#   warnings.warn(
# /home/emelnick/.local/lib/python3.9/site-packages/scipy/integrate/_quadrature.py:850: AccuracyWarning: divmax (10) exceeded. Latest difference = 1.209449e+07
#   warnings.warn(
# /home/emelnick/.local/lib/python3.9/site-packages/scipy/integrate/_quadrature.py:850: AccuracyWarning: divmax (10) exceeded. Latest difference = 1.086525e+07
#   warnings.warn(
# /home/emelnick/.local/lib/python3.9/site-packages/scipy/integrate/_quadrature.py:850: AccuracyWarning: divmax (10) exceeded. Latest difference = 9.807175e+06
#   warnings.warn(
# /home/emelnick/.local/lib/python3.9/site-packages/scipy/integrate/_quadrature.py:850: AccuracyWarning: divmax (10) exceeded. Latest difference = 8.859338e+06
#   warnings.warn(
# /home/emelnick/.local/lib/python3.9/site-packages/scipy/integrate/_quadrature.py:850: AccuracyWarning: divmax (10) exceeded. Latest difference = 7.972071e+06
#   warnings.warn(
# /home/emelnick/.local/lib/python3.9/site-packages/scipy/integrate/_quadrature.py:850: AccuracyWarning: divmax (10) exceeded. Latest difference = 7.143831e+06
#   warnings.warn(
# /home/emelnick/.local/lib/python3.9/site-packages/scipy/integrate/_quadrature.py:850: AccuracyWarning: divmax (10) exceeded. Latest difference = 6.417152e+06
#   warnings.warn(
# /home/emelnick/.local/lib/python3.9/site-packages/scipy/integrate/_quadrature.py:850: AccuracyWarning: divmax (10) exceeded. Latest difference = 5.781767e+06
#   warnings.warn(
# /home/emelnick/.local/lib/python3.9/site-packages/scipy/integrate/_quadrature.py:850: AccuracyWarning: divmax (10) exceeded. Latest difference = 5.189295e+06
#   warnings.warn(
# /home/emelnick/.local/lib/python3.9/site-packages/scipy/integrate/_quadrature.py:850: AccuracyWarning: divmax (10) exceeded. Latest difference = 4.638424e+06
#   warnings.warn(
# /home/emelnick/.local/lib/python3.9/site-packages/scipy/integrate/_quadrature.py:850: AccuracyWarning: divmax (10) exceeded. Latest difference = 4.146673e+06
#   warnings.warn(
# /home/emelnick/.local/lib/python3.9/site-packages/scipy/integrate/_quadrature.py:850: AccuracyWarning: divmax (10) exceeded. Latest difference = 3.726292e+06
#   warnings.warn(
# /home/emelnick/.local/lib/python3.9/site-packages/scipy/integrate/_quadrature.py:850: AccuracyWarning: divmax (10) exceeded. Latest difference = 3.335803e+06
#   warnings.warn(
# /home/emelnick/.local/lib/python3.9/site-packages/scipy/integrate/_quadrature.py:850: AccuracyWarning: divmax (10) exceeded. Latest difference = 2.974145e+06
#   warnings.warn(
# /home/emelnick/.local/lib/python3.9/site-packages/scipy/integrate/_quadrature.py:850: AccuracyWarning: divmax (10) exceeded. Latest difference = 2.652119e+06
#   warnings.warn(
# /home/emelnick/.local/lib/python3.9/site-packages/scipy/integrate/_quadrature.py:850: AccuracyWarning: divmax (10) exceeded. Latest difference = 2.410364e+06
#   warnings.warn(
# /home/emelnick/.local/lib/python3.9/site-packages/scipy/integrate/_quadrature.py:850: AccuracyWarning: divmax (10) exceeded. Latest difference = 2.184579e+06
#   warnings.warn(
# /home/emelnick/.local/lib/python3.9/site-packages/scipy/integrate/_quadrature.py:850: AccuracyWarning: divmax (10) exceeded. Latest difference = 1.974169e+06
#   warnings.warn(
# /home/emelnick/.local/lib/python3.9/site-packages/scipy/integrate/_quadrature.py:850: AccuracyWarning: divmax (10) exceeded. Latest difference = 1.778531e+06
#   warnings.warn(
# Text(0.5, 1.0, 'logarithmic m')

# %% [markdown]
# ## PS mass function plot

# %%
# z_vals = [0,12,16,18]
z_vals = np.linspace(0,20,101)
# z_vals = [0]
zeta = 40
i=3
Q_vals = []
for z in z_vals:
    mMin = 1e1
    rho = cosmos[i].rho_mean * (1+z)**3
    
    if (10*z)%15 == 0:
            m_valslin = np.linspace(1,16,100)
            m_valslog = np.logspace(1,16,100)
            
            plt.figure(0)
            plt.plot(m_valslin,bubbleFunc[i](10**m_valslin,z),label=z)
            plt.figure(1)
            plt.loglog(m_valslog,bubbleFunc[i](m_valslog,z),label=z)
            
plt.figure(0)
plt.yscale('log')
plt.ylim([1e-16,1e7])
plt.legend()

plt.figure(1)
plt.ylim([1e-16,1e7])
plt.legend()

# %% [markdown]
# While the plots are generally looking like the right shape, the $Q$ values are *really* small, which would suggest that the space being considered is barely ionized at all. Furlanetto was getting values between 0.01 and 1. If I had to guess, perhaps the issue is either with how $m_{\text{min}}$ is calculated or the bubble function $m\frac{\text{d}n}{\text{d}m}$. Maybe changing the barrier from $\delta_c(z),\sigma(m)$ to $\delta_c,\sigma(m,z)$ doesn't work as nicely as I thought.
#
# I also have noticed that Furlanetto uses Lagrangian coordinates, which other sources have talked about a bit, but I haven't been able to wrap my head around what that means or the implications of it. Is it something to be concerned about?
#
# doi:10.1093/mnras/stw1542 (Q integral from $r_\text{min}$to $\infty$)
#
# doi.org/10.48550/arXiv.1401.7994 (A bit on Euler/Lagrange coordinates, among other things)
#
# doi:10.1093/mnras/stw1060
#
# https://ned.ipac.caltech.edu/level5/Sept15/Johnson/Johnson1.html virial stuff

# %% [markdown]
# # III. Testing, Scratch, and Junk<a name="test"></a>

# %%
z = np.array([0,6,12,20])
mMin = (1.308695e-10) * ((cosmos[i].RHO_C*1000 * cosmos[i].OmegaM)**(-1/2)) * ((1+z)**(-3/2)) * (1e4)**(3/2) # Included Delta in pre-eval w/ cosmology.py OmegaM property and in solar masses
print(np.log10(mMin))
mMin = (3.95284708e8/cosmos[i].h) * (1/(1+z))**(3/2)
print(np.log10(mMin))
# Out:
# [9.26307159 7.99542453 7.59215656 7.27974265]
# [8.73957752 7.47193046 7.06866249 6.75624858]

# %%
T = 1e4
m_min1 = (1e8/cosmo0.h) * (10/(1+z) * T/(4e4))**(3/2)
print(m_min1)
print(np.log10(m_min1))
# Out:
# 11712847.480061824
# 7.068662488116533

# %%
z = 12
m_vals = np.logspace(9,15,100)
s2_vals0 = sigmaInt[0](m_vals,z)**2
s2_vals1 = sigmaInt[1](m_vals,z)**2
s2_vals2 = sigmaInt[2](m_vals,z)**2

plt.plot(s2_vals0,bubbleFunc[0].B(m_vals,z),label='h=0.005')
plt.plot(s2_vals1,bubbleFunc[1].B(m_vals,z),label='h=0.05')
plt.plot(s2_vals2,bubbleFunc[2].B(m_vals,z),label='h=0.5')
plt.legend()

a = bubbleFunc[0](m_vals,z)
a = bubbleFunc[1](m_vals,z)
a = bubbleFunc[2](m_vals,z)
# Out:
# C0 = 0.9586001449537348
# B0 = [9.42484818 9.42501322 9.42518321 9.42535836 9.42553902 9.42572532
#  9.42591757 9.42611606 9.4263211  9.42653307 9.42675218 9.42697874
#  9.42721314 9.42745584 9.42770717 9.42796746 9.42823714 9.42851668
#  9.4288066  9.42910738 9.42941933 9.42974309 9.4300792  9.43042834
#  9.43079107 9.43116781 9.43155931 9.43196634 9.43238972 9.43282994
#  9.43328768 9.43376382 9.43425925 9.43477487 9.43531117 9.43586894
#  9.43644914 9.43705273 9.43768051 9.43833281 9.43901037 9.43971401
#  9.44044446 9.44120199 9.44198638 9.44279791 9.44363671 9.44450272
#  9.44539488 9.44631191 9.44725286 9.44821648 9.4492011  9.4502035
#  9.45122077 9.45225021 9.45328871 9.45433262 9.45537661 9.45641644
#  9.45744807 9.45846736 9.45946957 9.46044901 9.46140167 9.46232398
#  9.46321274 9.46406423 9.46487501 9.46564317 9.46636733 9.46704663
#  9.46768014 9.46826787 9.46881015 9.46930803 9.46976303 9.47017628
#  9.47055053 9.47088777 9.47118951 9.47145925 9.47169972 9.47191211
#  9.47209874 9.47226374 9.47240923 9.47253543 9.4726443  9.47273936
#  9.47282292 9.47289552 9.47295735 9.47300977 9.47305487 9.47309432
#  9.47312887 9.47315872 9.47318407 9.47320545]
# C0 = 1.0546903087824826
# B0 = [ 9.90406754  9.90589253  9.90777643  9.90972126  9.91173068  9.91380561
#   9.91594933  9.91816473  9.92045501  9.92282404  9.92527404  9.92780809
#   9.93043018  9.93314527  9.9359567   9.93886784  9.94188303  9.94500729
#   9.94824614  9.95160469  9.95508578  9.95869651  9.96244241  9.9663305
#   9.97036681  9.97455541  9.9789042   9.98342117  9.98811501  9.99299028
#   9.99805414 10.00331585 10.0087842  10.01446861 10.02037395 10.02650811
#  10.03288076 10.0395016  10.04637842 10.05351403 10.06091546 10.06859068
#  10.07654623 10.08478423 10.09330178 10.10210079 10.11118091 10.12053997
#  10.1301661  10.14004494 10.15016445 10.1605091  10.17105903 10.1817811
#  10.1926436  10.20361526 10.21466075 10.22573955 10.23679961 10.24779491
#  10.25868054 10.26941074 10.27993664 10.29020507 10.30017324 10.30980255
#  10.31905876 10.32790796 10.33632043 10.34427653 10.35176217 10.35876915
#  10.36529205 10.3713343  10.37690191 10.38200684 10.38666717 10.39089524
#  10.39472154 10.39816685 10.40124693 10.40399913 10.40645308 10.40861931
#  10.41052118 10.41220365 10.41368847 10.41497506 10.41608296 10.41705011
#  10.41790195 10.41864207 10.41927062 10.41980057 10.42025457 10.42065145
#  10.42099976 10.42130008 10.42155249 10.4217614 ]
# C0 = 1.5297831254047747
# B0 = [11.14731335 11.19237134 11.23805906 11.2843577  11.33132143 11.37887335
#  11.42707341 11.47588978 11.52536211 11.57547329 11.62619244 11.67759975
#  11.72956753 11.78221477 11.83549677 11.88940454 11.94393837 11.99909171
#  12.05487727 12.11129064 12.16828498 12.22589869 12.28408943 12.34286858
#  12.40227361 12.46218957 12.52266111 12.58366472 12.64523551 12.70727654
#  12.7697855  12.8327628  12.89616893 12.9599975  13.02418929 13.08870721
#  13.15352607 13.21861006 13.28390915 13.34936303 13.41488508 13.48044886
#  13.5459746  13.61137135 13.67655309 13.74142336 13.80586541 13.86975569
#  13.93299368 13.9954523  14.05697003 14.11737532 14.17649735 14.23426522
#  14.29052088 14.34507049 14.39771691 14.44831437 14.4969051  14.54334766
#  14.58748737 14.6291903  14.66845976 14.70547065 14.74015613 14.77246893
#  14.80239679 14.83013271 14.85588829 14.87967615 14.90152924 14.92150168
#  14.93975733 14.95647037 14.97175561 14.98570788 14.99846257 15.01003879
#  15.02062763 15.03027414 15.03897479 15.04689704 15.0541823  15.06070267
#  15.06649249 15.07186291 15.07681565 15.08115003 15.08493622 15.08840628
#  15.09165102 15.09457634 15.09709616 15.09926926 15.10123323 15.10307286
#  15.10476477 15.10622986 15.10742998 15.10840516]

# %%
window = 'sharp_k'
intHelper = IntegrationHelper(2048)
z_vals_sigma = np.linspace(0,20,25) 

for i in range(len(cosmos)):
    sigmaInt[i] = SigmaInterpolator(cosmos[i],lin_power[i],growth[i],1e1,1e25,z_vals_sigma,intHelper,Nr=1024,window_function=window)
    sigmaInt[i].compute(1e-4,1e3)

# %%
mMin = (1.308695e-10) * ((cosmo0.RHO_C*1000 * cosmo0.OmegaM)**(-1/2)) * ((1+z)**(3/2)) * (1e4)**(3/2) # Included Delta in pre-eval w/ cosmology.py OmegaM property and in solar masses
